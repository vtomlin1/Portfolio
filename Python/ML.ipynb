# %% [markdown]
# <div style = "text-align:center">
#     <h1>Machine Learning</h1>
# </div>

# %% [markdown]
# Notes:
# - Buillt a simple linear regression model using SciKit learn.
# - Next: Keras and Tensorflow

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Pull preprocessiong function from a python script.
from Preprocessing import preprocess

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#Replace state, city, and zipcode categories with the average prices of each
average_prices_by_state = train.groupby('state')['price'].mean()
average_home_prices_by_city = train.groupby('city')['price'].mean()
average_home_prices_by_zipcode = train.groupby('zipcode')['price'].mean()

clean_train = preprocess(average_prices_by_state, average_home_prices_by_city, average_home_prices_by_zipcode, train)
clean_test = preprocess(average_prices_by_state, average_home_prices_by_city, average_home_prices_by_zipcode, test)

# %%
clean_train
# Out:
#           id  bathrooms  bedrooms  livingArea   lotArea  homeType_CONDO  \
# 0      20479        3.0       4.0      3078.0   7492.32               0
# 1      13019        3.0       3.0      2200.0      0.00               1
# 2       9816        5.0       5.0      3722.0   6577.56               0
# 3       4479        2.0       3.0      1388.0      0.00               1
# 4        180        4.0       3.0      2972.0  79714.80               0
# ...      ...        ...       ...         ...       ...             ...
# 23629  21575        2.0       3.0      1600.0   3600.00               0
# 23630   5390        2.0       3.0      1232.0  40946.40               0
# 23631    860        2.0       3.0      1605.0   6150.00               0
# 23632  15795        2.0       2.0      1810.0   8713.00               0
# 23633  23654        1.0       2.0       890.0   4356.00               0
#
#        homeType_MULTI_FAMILY  homeType_SINGLE_FAMILY  homeType_TOWNHOUSE  \
# ...

# %%
clean_test
# Out:
#          id  bathrooms  bedrooms  livingArea   lotArea  homeType_CONDO  \
# 0     22805        4.0       5.0      4100.0   10454.4               0
# 1     18392        3.0       4.0      2055.0   12632.4               0
# 2     15215        2.0       3.0      1530.0    4791.6               0
# 3     20235        1.0       3.0       744.0    6120.0               0
# 4     13810        3.0       6.0      4166.0      37.0               0
# ...     ...        ...       ...         ...       ...             ...
# 2622  15703        2.0       2.0      1560.0    7405.2               0
# 2623  23860        4.0       5.0      3860.0       0.0               0
# 2624   1450        2.0       3.0      1169.0       0.0               0
# 2625  26213        2.0       3.0      2220.0  219978.0               0
# 2626   5221        5.0       7.0      3908.0  279219.6               0
#
#       homeType_MULTI_FAMILY  homeType_SINGLE_FAMILY  homeType_TOWNHOUSE  \
# ...

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# I have used the scikit learn library to test out a simple linear regression model.

# %%
#Scikit learn library
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#Testing a linear regression model with all of the data. x is the input variables and y is the output.
X = clean_train.drop(['price'], axis=1)
y = clean_train['price']

errors = []

#Some randomness in the model, do this 4 times then find the average error
for i in range(4):
  #Split 80% of the data into training and 20% into testing.
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=i)
  model = LinearRegression()
  model.fit(X_train, y_train)
  predictions = model.predict(X_train)
  #MAE is the metric of accuracy
  errors.append(mean_absolute_error(predictions, y_train))

print(errors)
print(f'average error: {np.mean(errors)}')
# Out:
# [50717.31921743505, 50730.013053382594, 50858.64298843504, 50694.60611349019]
# average error: 50750.145343185715

# %% [markdown]
# The average error with the training data is $50,750.

# %% [markdown]
# Next:
# - Keras
# - Tensorflow
